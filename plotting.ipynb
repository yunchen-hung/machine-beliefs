# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['See', 'Hear', 'Discriminate colors', 'Discriminate distances',
'Think unsupported objects will fall', 'Think hidden objects are still there',
'Discriminate quantities', 'Preder helping to not helping', 'Read']
values = [25, 40, 30, 55]

plt.scatter(values, np.arange(len(categories)), marker='s', s=200, color='skyblue', edgecolors='black')
