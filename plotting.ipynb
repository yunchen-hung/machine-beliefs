# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['See', 'Hear', 'Discriminate colors', 'Discriminate distances',
'Think unsupported objects will fall', 'Think hidden objects are still there',
'Discriminate quantities', 'Prefer helping to not helping', 'Read']
values = ["<=.5", ".5-1", "<=.5", "<=.5", "<=.5", ".5-1", "2-4", "2-4" ,"2-4"]
custom_labels = ["<=.5", ".5-1", "1-2", "2-4"]

plt.scatter(values, categories, marker='s', s=200, color='skyblue', edgecolors='black')
plt.xticks(ticks=x, labels=custom_labels, rotation=45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 17
#      15     else:
#      16         plt.scatter([cat] * len(subset), subset, marker='s', s=200, color='skyblue')
# ---> 17 plt.xticks(ticks=values, labels=custom_labels, rotation=45)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\pyplot.py:2246, in xticks(ticks, labels, minor, **kwargs)
#    2244         l._internal_update(kwargs)
#    2245 else:
# -> 2246     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    2248 return locs, labels_out
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\axis.py:2106, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2102 elif isinstance(locator, mticker.FixedLocator):
#    2103     # Passing [] as a list of labels is often used as a way to
#    2104     # remove all tick labels, so only error for > 0 labels
#    2105     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2106         raise ValueError(
#    2107             "The number of FixedLocator locations"
#    2108             f" ({len(locator.locs)}), usually from a call to"
#    2109             " set_ticks, does not match"
#    2110             f" the number of labels ({len(labels)}).")
#    2111     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2112     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (9), usually from a call to set_ticks, does not match the number of labels (4).

# %%
categories[np.where(values == "<=.5")]
# Out:
# array(['See', 'Discriminate colors', 'Discriminate distances',
#        'Think hidden objects are still there'], dtype='<U36')

# %%
[cat] * len(subset)
# Out:
# [np.str_('2-4'), np.str_('2-4'), np.str_('2-4'), np.str_('2-4')]
